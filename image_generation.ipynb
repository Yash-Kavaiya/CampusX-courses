# %%
from openai import OpenAI
import requests
from PIL import Image
from io import BytesIO


# Initialize OpenAI client
client = OpenAI(api_key="sk-proj-u1VfWincqmhEVPRO6c0mT3BlbkFJ2NwW2NDVX2QdkUZsKjjX")



# Set the prompt
prompt = "Generate a monkey working on a computer and writing program in Python."

# call the OpenAI API
response = client.images.generate(
    model = "dall-e-3",
    prompt=prompt,
    n=1,
    size="1024x1024",
    response_format="url",
)

generated_image_url = response.data[0].url
print(generated_image_url)

generated_image = requests.get(generated_image_url).content

# Open the image
display(Image.open(BytesIO(generated_image)))
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-4JTxkC0JrRKkB86UtJkNzphD/user-x5qg5WfvRStczaJQrlLeivhe/img-ZGE4Zg3bgN8FMs3RlG4RAg99.png?st=2024-05-16T15%3A02%3A47Z&se=2024-05-16T17%3A02%3A47Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-05-16T15%3A37%3A59Z&ske=2024-05-17T15%3A37%3A59Z&sks=b&skv=2021-08-06&sig=Opa8uIV5pbNGbdOFHNi0pA2nFNrX4cytX%2Bp2/8IvdIA%3D
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %%
! pip install openai requests pillow
# Out:
# Requirement already satisfied: openai in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (1.30.1)
# Requirement already satisfied: requests in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: pillow in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (10.3.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from openai) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/mokarbeen/Desktop/GenAI_for_Vision/venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
